# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/Salary_Data.csv")

# %%
max(df.Salary)
# Out:
# 122391.0

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
print(df.iloc[0][0])
#print(x)
#print(y)
# Out:
# 1.1

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.predict([[6.5]])
# Out:
# array([86274.03879531])

# %%
y_hat = regressor.predict(x_test)

# %%
plt.scatter(x_train, y_train, color="red") #Plotting the points
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.plot(x_train, regressor.predict(x_train), color='blue') #Drawing regression line
plt.title("Salary vs Experience (Training set)")
plt.show()

# %%
plt.scatter(x_test, y_test, color="red") #Plotting the points
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.plot(x_train, regressor.predict(x_train), color='blue') #Drawing regression line
plt.title("Salary vs Experience (Training set)")
plt.show()
